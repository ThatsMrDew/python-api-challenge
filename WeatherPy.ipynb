# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = (requests.get(city_url)).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sasebo
# Processing Record 2 of Set 1 | kupang
# Processing Record 3 of Set 1 | west island
# Processing Record 4 of Set 1 | silver city
# Processing Record 5 of Set 1 | petauke
# Processing Record 6 of Set 1 | badger
# Processing Record 7 of Set 1 | constantia
# Processing Record 8 of Set 1 | black forest
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | mugia
# Processing Record 11 of Set 1 | dawson creek
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | nar'yan-mar
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | wailua homesteads
# Processing Record 16 of Set 1 | hawaiian paradise park
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | pantai remis
# Processing Record 19 of Set 1 | susuman
# Processing Record 20 of Set 1 | bodo
# Processing Record 21 of Set 1 | port shepstone
# Processing Record 22 of Set 1 | sandnessjoen
# Processing Record 23 of Set 1 | hami
# Processing Record 24 of Set 1 | port lincoln
# Processing Record 25 of Set 1 | codrington
# Processing Record 26 of Set 1 | gisborne
# Processing Record 27 of Set 1 | annaba
# Processing Record 28 of Set 1 | bubaque
# Processing Record 29 of Set 1 | saquarema
# Processing Record 30 of Set 1 | tazovsky
# Processing Record 31 of Set 1 | adamstown
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | whitehorse
# Processing Record 34 of Set 1 | waitangi
# Processing Record 35 of Set 1 | coldwater
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | timbuktu
# Processing Record 38 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 39 of Set 1 | holualoa
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | edinburgh of the seven seas
# Processing Record 44 of Set 1 | portland
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | uturoa
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | arkhangel'sk
# Processing Record 50 of Set 1 | tiksi
# Processing Record 0 of Set 2 | alotau
# Processing Record 1 of Set 2 | dubois
# Processing Record 2 of Set 2 | udachny
# Processing Record 3 of Set 2 | kailua-kona
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | saint-francois
# Processing Record 7 of Set 2 | qaqortoq
# Processing Record 8 of Set 2 | san antonio de pale
# Processing Record 9 of Set 2 | isafjordur
# Processing Record 10 of Set 2 | aykhal
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | margaret river
# Processing Record 13 of Set 2 | duragan
# Processing Record 14 of Set 2 | weno
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | nieuw amsterdam
# Processing Record 17 of Set 2 | irymple
# Processing Record 18 of Set 2 | urengoy
# Processing Record 19 of Set 2 | kolonia town
# Processing Record 20 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 21 of Set 2 | dukhovnitskoye
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | chingirlau
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | shijak
# Processing Record 26 of Set 2 | ust-nera
# Processing Record 27 of Set 2 | korenevo
# Processing Record 28 of Set 2 | lhasa
# Processing Record 29 of Set 2 | puerto natales
# Processing Record 30 of Set 2 | port macquarie
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | hamilton
# Processing Record 33 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 34 of Set 2 | santa ana
# Processing Record 35 of Set 2 | blackmans bay
# Processing Record 36 of Set 2 | bomdila
# Processing Record 37 of Set 2 | fuglafjordur
# Processing Record 38 of Set 2 | invercargill
# Processing Record 39 of Set 2 | hammerfest
# Processing Record 40 of Set 2 | wacheng
# Processing Record 41 of Set 2 | gulf shores
# Processing Record 42 of Set 2 | castillos
# Processing Record 43 of Set 2 | kroya
# Processing Record 44 of Set 2 | vilyuchinsk
# Processing Record 45 of Set 2 | ghanzi
# Processing Record 46 of Set 2 | nova sintra
# Processing Record 47 of Set 2 | boguchany
# Processing Record 48 of Set 2 | aginskoye
# Processing Record 49 of Set 2 | gamba
# Processing Record 0 of Set 3 | berdigestyakh
# Processing Record 1 of Set 3 | kirakira
# Processing Record 2 of Set 3 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | aras-asan
# Processing Record 4 of Set 3 | lichinga
# Processing Record 5 of Set 3 | thames
# Processing Record 6 of Set 3 | xai-xai
# Processing Record 7 of Set 3 | bardai
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | taksimo
# Processing Record 10 of Set 3 | broome
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | tura
# Processing Record 13 of Set 3 | fort st. john
# Processing Record 14 of Set 3 | dudinka
# Processing Record 15 of Set 3 | biarritz
# Processing Record 16 of Set 3 | bilibino
# Processing Record 17 of Set 3 | sitka
# Processing Record 18 of Set 3 | alo
# Processing Record 19 of Set 3 | nemuro
# Processing Record 20 of Set 3 | prince rupert
# Processing Record 21 of Set 3 | longjiang
# Processing Record 22 of Set 3 | guerrero negro
# Processing Record 23 of Set 3 | palikir - national government center
# Processing Record 24 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 25 of Set 3 | mount pearl
# Processing Record 26 of Set 3 | porbandar
# Processing Record 27 of Set 3 | bukittinggi
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | birzebbuga
# Processing Record 30 of Set 3 | bamboo flat
# Processing Record 31 of Set 3 | tonekabon
# Processing Record 32 of Set 3 | olonkinbyen
# Processing Record 33 of Set 3 | stanley
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | vorgashor
# Processing Record 36 of Set 3 | chichiriviche
# Processing Record 37 of Set 3 | misawa
# Processing Record 38 of Set 3 | usogorsk
# Processing Record 39 of Set 3 | shakawe
# Processing Record 40 of Set 3 | gemena
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | stepnogorsk
# Processing Record 43 of Set 3 | whangarei
# Processing Record 44 of Set 3 | anadyr
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | port mathurin
# Processing Record 47 of Set 3 | ondjiva
# Processing Record 48 of Set 3 | miri
# Processing Record 49 of Set 3 | mana
# Processing Record 0 of Set 4 | aromashevo
# Processing Record 1 of Set 4 | yambio
# Processing Record 2 of Set 4 | raja
# Processing Record 3 of Set 4 | lubango
# Processing Record 4 of Set 4 | geraldton
# Processing Record 5 of Set 4 | neftcala
# Processing Record 6 of Set 4 | shimokizukuri
# Processing Record 7 of Set 4 | armacao de buzios
# Processing Record 8 of Set 4 | ujae
# Processing Record 9 of Set 4 | kone
# Processing Record 10 of Set 4 | hastings
# Processing Record 11 of Set 4 | corner brook
# Processing Record 12 of Set 4 | sherman
# Processing Record 13 of Set 4 | ulsteinvik
# Processing Record 14 of Set 4 | utrik
# Processing Record 15 of Set 4 | dongola
# Processing Record 16 of Set 4 | aasiaat
# Processing Record 17 of Set 4 | baruun-urt
# Processing Record 18 of Set 4 | flying fish cove
# Processing Record 19 of Set 4 | taganrog
# Processing Record 20 of Set 4 | ta`u
# Processing Record 21 of Set 4 | brisas de zicatela
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | urumqi
# Processing Record 24 of Set 4 | harlingen
# Processing Record 25 of Set 4 | papao
# Processing Record 26 of Set 4 | mount isa
# Processing Record 27 of Set 4 | papatowai
# Processing Record 28 of Set 4 | vallenar
# Processing Record 29 of Set 4 | la ronge
# Processing Record 30 of Set 4 | watsa
# Processing Record 31 of Set 4 | kitimat
# Processing Record 32 of Set 4 | iskateley
# Processing Record 33 of Set 4 | brooks
# Processing Record 34 of Set 4 | bandon
# Processing Record 35 of Set 4 | gokwe
# Processing Record 36 of Set 4 | dunedin
# Processing Record 37 of Set 4 | afaahiti
# Processing Record 38 of Set 4 | el granada
# Processing Record 39 of Set 4 | vikhorevka
# Processing Record 40 of Set 4 | haiku-pauwela
# Processing Record 41 of Set 4 | enewetak
# Processing Record 42 of Set 4 | callao
# Processing Record 43 of Set 4 | howard springs
# Processing Record 44 of Set 4 | bantogon
# Processing Record 45 of Set 4 | mazagao
# Processing Record 46 of Set 4 | twon-brass
# Processing Record 47 of Set 4 | naracoorte
# Processing Record 48 of Set 4 | naberera
# Processing Record 49 of Set 4 | gorontalo
# Processing Record 0 of Set 5 | cabo san lucas
# Processing Record 1 of Set 5 | mammoth lakes
# Processing Record 2 of Set 5 | ocean shores
# Processing Record 3 of Set 5 | bridgewater
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | mpulungu
# Processing Record 6 of Set 5 | chonchi
# Processing Record 7 of Set 5 | huai khot
# Processing Record 8 of Set 5 | pemba
# Processing Record 9 of Set 5 | arsen'yev
# Processing Record 10 of Set 5 | severo-yeniseyskiy
# Processing Record 11 of Set 5 | tilcara
# Processing Record 12 of Set 5 | santana
# Processing Record 13 of Set 5 | waingapu
# Processing Record 14 of Set 5 | peniche
# Processing Record 15 of Set 5 | nabire
# Processing Record 16 of Set 5 | kot diji
# Processing Record 17 of Set 5 | la peca
# Processing Record 18 of Set 5 | santa cruz
# Processing Record 19 of Set 5 | la'ie
# Processing Record 20 of Set 5 | cozumel
# Processing Record 21 of Set 5 | noumea
# Processing Record 22 of Set 5 | st. john's
# Processing Record 23 of Set 5 | saipan
# Processing Record 24 of Set 5 | ca mau
# Processing Record 25 of Set 5 | happy valley-goose bay
# Processing Record 26 of Set 5 | al burayqah
# Processing Record 27 of Set 5 | chaozhou
# Processing Record 28 of Set 5 | tanki leendert
# City not found. Skipping...
# Processing Record 29 of Set 5 | vorkuta
# Processing Record 30 of Set 5 | kandyagash
# Processing Record 31 of Set 5 | nguti
# Processing Record 32 of Set 5 | medina de pomar
# Processing Record 33 of Set 5 | karratha
# Processing Record 34 of Set 5 | tolanaro
# Processing Record 35 of Set 5 | lucea
# Processing Record 36 of Set 5 | karpinsk
# Processing Record 37 of Set 5 | chatham
# Processing Record 38 of Set 5 | pointe-noire
# Processing Record 39 of Set 5 | cobija
# Processing Record 40 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 41 of Set 5 | dullewala
# Processing Record 42 of Set 5 | tabou
# Processing Record 43 of Set 5 | lianzhou
# Processing Record 44 of Set 5 | wanning
# Processing Record 45 of Set 5 | selfoss
# Processing Record 46 of Set 5 | vetluzhskiy
# Processing Record 47 of Set 5 | pacasmayo
# Processing Record 48 of Set 5 | yuzhno-kurilsk
# Processing Record 49 of Set 5 | amga
# Processing Record 0 of Set 6 | posto fiscal rolim de moura
# Processing Record 1 of Set 6 | namtsy
# Processing Record 2 of Set 6 | nuuk
# Processing Record 3 of Set 6 | las trojes
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | taoyuan city
# Processing Record 6 of Set 6 | bikenibeu village
# Processing Record 7 of Set 6 | malayer
# Processing Record 8 of Set 6 | mhlume
# Processing Record 9 of Set 6 | ntungamo
# Processing Record 10 of Set 6 | king city
# Processing Record 11 of Set 6 | anshun
# Processing Record 12 of Set 6 | mbeya
# Processing Record 13 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 6 | slave lake
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | chibougamau
# Processing Record 17 of Set 6 | saynshand
# Processing Record 18 of Set 6 | roma
# Processing Record 19 of Set 6 | atafu village
# Processing Record 20 of Set 6 | haenam
# Processing Record 21 of Set 6 | big spring
# Processing Record 22 of Set 6 | san ignacio rio muerto
# Processing Record 23 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 6 | nadi
# Processing Record 25 of Set 6 | kuraymah
# Processing Record 26 of Set 6 | san pedro pochutla
# Processing Record 27 of Set 6 | sovetskaya gavan'
# Processing Record 28 of Set 6 | batang
# Processing Record 29 of Set 6 | bandundu
# Processing Record 30 of Set 6 | taltal
# Processing Record 31 of Set 6 | bowen
# Processing Record 32 of Set 6 | mizdah
# Processing Record 33 of Set 6 | ulladulla
# Processing Record 34 of Set 6 | al kharijah
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | sarakhs
# Processing Record 37 of Set 6 | college
# Processing Record 38 of Set 6 | mar del plata
# Processing Record 39 of Set 6 | soe
# Processing Record 40 of Set 6 | turpan
# Processing Record 41 of Set 6 | kidal
# Processing Record 42 of Set 6 | tagab
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | fortuna
# Processing Record 45 of Set 6 | rawson
# Processing Record 46 of Set 6 | polyarnyy
# Processing Record 47 of Set 6 | new norfolk
# Processing Record 48 of Set 6 | jasaan
# Processing Record 49 of Set 6 | kuytun
# Processing Record 0 of Set 7 | zangguy
# City not found. Skipping...
# Processing Record 1 of Set 7 | chenzhou
# Processing Record 2 of Set 7 | zaozhuang
# Processing Record 3 of Set 7 | suva
# Processing Record 4 of Set 7 | kingston
# Processing Record 5 of Set 7 | pangody
# Processing Record 6 of Set 7 | kudahuvadhoo
# Processing Record 7 of Set 7 | cururupu
# Processing Record 8 of Set 7 | tofol
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | cestos city
# Processing Record 11 of Set 7 | levuka
# Processing Record 12 of Set 7 | lata
# Processing Record 13 of Set 7 | antofagasta
# Processing Record 14 of Set 7 | nema
# Processing Record 15 of Set 7 | mejit
# Processing Record 16 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 17 of Set 7 | trogir
# Processing Record 18 of Set 7 | quellon
# Processing Record 19 of Set 7 | mega
# Processing Record 20 of Set 7 | jamestown
# Processing Record 21 of Set 7 | dhulikhel
# Processing Record 22 of Set 7 | glace bay
# Processing Record 23 of Set 7 | naliya
# Processing Record 24 of Set 7 | as sulayyil
# Processing Record 25 of Set 7 | miyaly
# Processing Record 26 of Set 7 | gambela
# Processing Record 27 of Set 7 | ulanhot
# Processing Record 28 of Set 7 | okuchi-shinohara
# Processing Record 29 of Set 7 | khovd
# Processing Record 30 of Set 7 | phibun mangsahan
# Processing Record 31 of Set 7 | behshahr
# Processing Record 32 of Set 7 | klyuchi
# Processing Record 33 of Set 7 | lihue
# Processing Record 34 of Set 7 | susaki
# Processing Record 35 of Set 7 | keflavik
# Processing Record 36 of Set 7 | labasa
# Processing Record 37 of Set 7 | ballina
# Processing Record 38 of Set 7 | hadibu
# Processing Record 39 of Set 7 | mercedes
# Processing Record 40 of Set 7 | guadalupe y calvo
# Processing Record 41 of Set 7 | kurchatov
# Processing Record 42 of Set 7 | al ghayzah
# Processing Record 43 of Set 7 | vilyuysk
# Processing Record 44 of Set 7 | punta arenas
# Processing Record 45 of Set 7 | savave village
# City not found. Skipping...
# Processing Record 46 of Set 7 | patacamaya
# Processing Record 47 of Set 7 | queenstown
# Processing Record 48 of Set 7 | kerben
# Processing Record 49 of Set 7 | xining
# Processing Record 0 of Set 8 | kapuskasing
# Processing Record 1 of Set 8 | ulundi
# Processing Record 2 of Set 8 | wenzhou
# Processing Record 3 of Set 8 | neryungri
# Processing Record 4 of Set 8 | tralee
# Processing Record 5 of Set 8 | vernon
# Processing Record 6 of Set 8 | aqsay
# Processing Record 7 of Set 8 | hit
# Processing Record 8 of Set 8 | mogadishu
# Processing Record 9 of Set 8 | kollam
# Processing Record 10 of Set 8 | villarrobledo
# Processing Record 11 of Set 8 | vidyayevo
# Processing Record 12 of Set 8 | antsiranana
# Processing Record 13 of Set 8 | chiras
# Processing Record 14 of Set 8 | westport
# Processing Record 15 of Set 8 | newman
# Processing Record 16 of Set 8 | danilov
# Processing Record 17 of Set 8 | san carlos
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | ormond-by-the-sea
# Processing Record 20 of Set 8 | east london
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | sao vicente
# Processing Record 23 of Set 8 | plettenberg bay
# Processing Record 24 of Set 8 | porto novo
# Processing Record 25 of Set 8 | jeju city
# Processing Record 26 of Set 8 | mitchell
# Processing Record 27 of Set 8 | beyneu
# Processing Record 28 of Set 8 | tibanbang
# Processing Record 29 of Set 8 | lobito
# Processing Record 30 of Set 8 | coari
# Processing Record 31 of Set 8 | fuerte olimpo
# Processing Record 32 of Set 8 | greenville
# Processing Record 33 of Set 8 | humberto de campos
# Processing Record 34 of Set 8 | daru
# Processing Record 35 of Set 8 | red hill
# Processing Record 36 of Set 8 | winkler
# Processing Record 37 of Set 8 | rikaze
# Processing Record 38 of Set 8 | bonthe
# Processing Record 39 of Set 8 | zhuanghe
# Processing Record 40 of Set 8 | copala
# Processing Record 41 of Set 8 | baiquan
# Processing Record 42 of Set 8 | hithadhoo
# Processing Record 43 of Set 8 | kataba
# Processing Record 44 of Set 8 | gadzhiyevo
# Processing Record 45 of Set 8 | shingu
# Processing Record 46 of Set 8 | vila velha
# Processing Record 47 of Set 8 | mossel bay
# Processing Record 48 of Set 8 | crixas
# Processing Record 49 of Set 8 | conduaga
# Processing Record 0 of Set 9 | malumfashi
# Processing Record 1 of Set 9 | sumenep
# Processing Record 2 of Set 9 | nilgiri
# Processing Record 3 of Set 9 | kayar
# Processing Record 4 of Set 9 | yuanping
# Processing Record 5 of Set 9 | walvis bay
# Processing Record 6 of Set 9 | regina
# Processing Record 7 of Set 9 | horta
# Processing Record 8 of Set 9 | auki
# Processing Record 9 of Set 9 | mekhe
# Processing Record 10 of Set 9 | santiago de cao
# Processing Record 11 of Set 9 | pyay
# Processing Record 12 of Set 9 | usinsk
# Processing Record 13 of Set 9 | natal
# Processing Record 14 of Set 9 | plastun
# Processing Record 15 of Set 9 | zhaqsy
# Processing Record 16 of Set 9 | hue
# Processing Record 17 of Set 9 | sevastopol
# Processing Record 18 of Set 9 | basco
# Processing Record 19 of Set 9 | tarancon
# Processing Record 20 of Set 9 | sinop
# Processing Record 21 of Set 9 | mizhou
# Processing Record 22 of Set 9 | olinda
# Processing Record 23 of Set 9 | nizhniy ingash
# Processing Record 24 of Set 9 | crane
# Processing Record 25 of Set 9 | sinsheim
# Processing Record 26 of Set 9 | maintirano
# Processing Record 27 of Set 9 | nizhnesortymskiy
# Processing Record 28 of Set 9 | rio grande
# Processing Record 29 of Set 9 | kenai
# Processing Record 30 of Set 9 | mangrol
# Processing Record 31 of Set 9 | tambopata
# Processing Record 32 of Set 9 | burela de cabo
# Processing Record 33 of Set 9 | minas de marcona
# Processing Record 34 of Set 9 | leava
# Processing Record 35 of Set 9 | boumagueur
# Processing Record 36 of Set 9 | alenquer
# Processing Record 37 of Set 9 | fuyu
# Processing Record 38 of Set 9 | arkalyk
# Processing Record 39 of Set 9 | sampit
# Processing Record 40 of Set 9 | stornoway
# Processing Record 41 of Set 9 | abraham's bay
# City not found. Skipping...
# Processing Record 42 of Set 9 | kursk
# Processing Record 43 of Set 9 | shatrovo
# Processing Record 44 of Set 9 | qamdo
# Processing Record 45 of Set 9 | motygino
# Processing Record 46 of Set 9 | luena
# Processing Record 47 of Set 9 | hasaki
# Processing Record 48 of Set 9 | shenkursk
# Processing Record 49 of Set 9 | san miguel el alto
# Processing Record 0 of Set 10 | bouar
# Processing Record 1 of Set 10 | nizhneangarsk
# Processing Record 2 of Set 10 | vila franca do campo
# Processing Record 3 of Set 10 | brookings
# Processing Record 4 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 5 of Set 10 | burley
# Processing Record 6 of Set 10 | floro
# Processing Record 7 of Set 10 | nizhnyaya poyma
# Processing Record 8 of Set 10 | cavan
# Processing Record 9 of Set 10 | bonga
# Processing Record 10 of Set 10 | antonio enes
# Processing Record 11 of Set 10 | swakopmund
# Processing Record 12 of Set 10 | lautoka
# Processing Record 13 of Set 10 | raduzhny
# Processing Record 14 of Set 10 | alaghsas
# Processing Record 15 of Set 10 | luderitz
# Processing Record 16 of Set 10 | tocache
# Processing Record 17 of Set 10 | oranjemund
# Processing Record 18 of Set 10 | bosaso
# Processing Record 19 of Set 10 | bela
# Processing Record 20 of Set 10 | ormara
# Processing Record 21 of Set 10 | alamos
# Processing Record 22 of Set 10 | vrangel'
# Processing Record 23 of Set 10 | serdar
# Processing Record 24 of Set 10 | bighapur khurd
# Processing Record 25 of Set 10 | fairwood
# Processing Record 26 of Set 10 | sisimiut
# Processing Record 27 of Set 10 | vac
# Processing Record 28 of Set 10 | orapa
# Processing Record 29 of Set 10 | kirensk
# Processing Record 30 of Set 10 | malango
# Processing Record 31 of Set 10 | gundlupet
# Processing Record 32 of Set 10 | nanzhang chengguanzhen
# Processing Record 33 of Set 10 | kuching
# Processing Record 34 of Set 10 | fale old settlement
# Processing Record 35 of Set 10 | xinhui
# Processing Record 36 of Set 10 | chortkiv
# Processing Record 37 of Set 10 | angermunde
# Processing Record 38 of Set 10 | cerritos
# Processing Record 39 of Set 10 | mata-utu
# Processing Record 40 of Set 10 | tobi village
# City not found. Skipping...
# Processing Record 41 of Set 10 | kaa-khem
# Processing Record 42 of Set 10 | richards bay
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | puerto armuelles
# Processing Record 45 of Set 10 | marudi
# City not found. Skipping...
# Processing Record 46 of Set 10 | i-n-salah
# Processing Record 47 of Set 10 | mitu
# Processing Record 48 of Set 10 | gaspe
# Processing Record 49 of Set 10 | uliastay
# Processing Record 0 of Set 11 | antsohimbondrona
# City not found. Skipping...
# Processing Record 1 of Set 11 | alice springs
# Processing Record 2 of Set 11 | sao joao dos patos
# Processing Record 3 of Set 11 | mount gambier
# Processing Record 4 of Set 11 | constitucion
# Processing Record 5 of Set 11 | revda
# Processing Record 6 of Set 11 | saint-pierre
# Processing Record 7 of Set 11 | yeniseysk
# Processing Record 8 of Set 11 | tan-tan
# Processing Record 9 of Set 11 | kelme
# Processing Record 10 of Set 11 | imbituba
# Processing Record 11 of Set 11 | chittarkonda
# Processing Record 12 of Set 11 | green river
# Processing Record 13 of Set 11 | kisumu
# Processing Record 14 of Set 11 | santyoku
# Processing Record 15 of Set 11 | makokou
# Processing Record 16 of Set 11 | charthawal
# Processing Record 17 of Set 11 | inhambane
# Processing Record 18 of Set 11 | gagliano del capo
# Processing Record 19 of Set 11 | ishtixon shahri
# City not found. Skipping...
# Processing Record 20 of Set 11 | barra de santo antonio
# Processing Record 21 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 22 of Set 11 | bachajon
# Processing Record 23 of Set 11 | cabedelo
# Processing Record 24 of Set 11 | el abiodh sidi cheikh
# Processing Record 25 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 26 of Set 11 | ingeniero jacobacci
# Processing Record 27 of Set 11 | al ain city
# Processing Record 28 of Set 11 | manapparai
# Processing Record 29 of Set 11 | murghob
# Processing Record 30 of Set 11 | aripuana
# Processing Record 31 of Set 11 | wuwei
# Processing Record 32 of Set 11 | songyuan
# Processing Record 33 of Set 11 | ghat
# Processing Record 34 of Set 11 | sao raimundo nonato
# Processing Record 35 of Set 11 | broken hill
# Processing Record 36 of Set 11 | stephenville
# Processing Record 37 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 38 of Set 11 | moussoro
# Processing Record 39 of Set 11 | buala
# Processing Record 40 of Set 11 | tukrah
# Processing Record 41 of Set 11 | tromso
# Processing Record 42 of Set 11 | krasnoturansk
# Processing Record 43 of Set 11 | yen vinh
# Processing Record 44 of Set 11 | itamaraca
# Processing Record 45 of Set 11 | ribeira brava
# Processing Record 46 of Set 11 | kozarska dubica
# Processing Record 47 of Set 11 | kavieng
# Processing Record 48 of Set 11 | brezina
# Processing Record 49 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 0 of Set 12 | nadym
# Processing Record 1 of Set 12 | ilebo
# Processing Record 2 of Set 12 | dakhla
# Processing Record 3 of Set 12 | remire-montjoly
# Processing Record 4 of Set 12 | biloela
# Processing Record 5 of Set 12 | magong
# Processing Record 6 of Set 12 | miches
# Processing Record 7 of Set 12 | baldoyle
# Processing Record 8 of Set 12 | valera
# Processing Record 9 of Set 12 | robbah
# Processing Record 10 of Set 12 | shambu
# Processing Record 11 of Set 12 | aioun
# Processing Record 12 of Set 12 | vershino-darasunskiy
# Processing Record 13 of Set 12 | kokkola
# Processing Record 14 of Set 12 | jaisalmer
# Processing Record 15 of Set 12 | yeppoon
# Processing Record 16 of Set 12 | san luis de la loma
# Processing Record 17 of Set 12 | woolgoolga
# Processing Record 18 of Set 12 | ikryanoye
# Processing Record 19 of Set 12 | jawf al maqbabah
# Processing Record 20 of Set 12 | mahabe
# City not found. Skipping...
# Processing Record 21 of Set 12 | ternate
# Processing Record 22 of Set 12 | charters towers
# Processing Record 23 of Set 12 | muzayri'
# City not found. Skipping...
# Processing Record 24 of Set 12 | kununurra
# Processing Record 25 of Set 12 | bocas del toro
# Processing Record 26 of Set 12 | bodaybo
# Processing Record 27 of Set 12 | rongelap
# Processing Record 28 of Set 12 | katsuura
# Processing Record 29 of Set 12 | saldanha
# Processing Record 30 of Set 12 | baillif
# Processing Record 31 of Set 12 | northam
# Processing Record 32 of Set 12 | tafuna
# Processing Record 33 of Set 12 | zaysan
# Processing Record 34 of Set 12 | flekkefjord
# Processing Record 35 of Set 12 | sinan
# Processing Record 36 of Set 12 | penistone
# Processing Record 37 of Set 12 | betong
# Processing Record 38 of Set 12 | tres passos
# Processing Record 39 of Set 12 | fort bragg
# Processing Record 40 of Set 12 | lorengau
# Processing Record 41 of Set 12 | muromtsevo
# Processing Record 42 of Set 12 | roxboro
# Processing Record 43 of Set 12 | port saint john's
# Processing Record 44 of Set 12 | east ballina
# Processing Record 45 of Set 12 | mpika
# Processing Record 46 of Set 12 | ust'-kulom
# Processing Record 47 of Set 12 | guiuan
# Processing Record 48 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 49 of Set 12 | canatlan
# Processing Record 0 of Set 13 | menongue
# Processing Record 1 of Set 13 | madera acres
# Processing Record 2 of Set 13 | taichung
# Processing Record 3 of Set 13 | colonia
# Processing Record 4 of Set 13 | mormugao
# Processing Record 5 of Set 13 | talcahuano
# Processing Record 6 of Set 13 | les cayes
# Processing Record 7 of Set 13 | nizhnevartovsk
# Processing Record 8 of Set 13 | carutapera
# Processing Record 9 of Set 13 | muleshoe
# Processing Record 10 of Set 13 | mokhsogollokh
# Processing Record 11 of Set 13 | tank
# Processing Record 12 of Set 13 | coahuayana de hidalgo
# Processing Record 13 of Set 13 | fuvahmulah
# City not found. Skipping...
# Processing Record 14 of Set 13 | acarau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       sasebo  33.1592  129.7228     14.06        31         100        0.72
# 1       kupang -10.1667  123.5833     31.32        79          20        4.12
# 2  west island -12.1568   96.8225     29.99        89          75        5.66
# 3  silver city  32.7701 -108.2803     15.17        16           0        5.81
# 4      petauke -14.2426   31.3253     18.70        97         100        1.07
#
#   Country        Date
# 0      JP  1740624557
# 1      ID  1740624386
# 2      CC  1740624559
# 3      US  1740624560
# 4      ZM  1740624561

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             sasebo  33.1592  129.7228     14.06        31         100
# 1             kupang -10.1667  123.5833     31.32        79          20
# 2        west island -12.1568   96.8225     29.99        89          75
# 3        silver city  32.7701 -108.2803     15.17        16           0
# 4            petauke -14.2426   31.3253     18.70        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.72      JP  1740624557
# 1              4.12      ID  1740624386
# 2              5.66      CC  1740624559
# 3              5.81      US  1740624560
# 4              1.07      ZM  1740624561

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Max Temp'], city_data_df['Lat'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Humidity'], city_data_df['Lat'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Cloudiness'], city_data_df['Lat'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Wind Speed'], city_data_df['Lat'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def linear_regress(x, y, eqn_coordinates):
    r = st.pearsonr(x, y)
    print(f"The r-value is: {r[0]}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y ={slope: .2f}x +{intercept: .2f}"
    plt.plot(x, regress_values, "r-")
    plt.annotate(line_eq, eqn_coordinates, fontsize=12, color="red")
    plt.scatter(x, y)
    plt.xlabel(f"{x.name}")
    plt.ylabel(f"{y.name}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
nh_df = city_data_df.loc[city_data_df['Lat'] >=0]

# Display sample data
nh_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              sasebo  33.1592  129.7228     14.06        31         100
# 3         silver city  32.7701 -108.2803     15.17        16           0
# 5              badger  64.8000 -147.5333     -7.86        54          75
# 6          constantia  44.1833   28.6500      3.38        88          97
# 7        black forest  39.0131 -104.7008      0.44        50           0
#
#          Wind Speed Country        Date
# City_ID
# 0              0.72      JP  1740624557
# 3              5.81      US  1740624560
# 5              3.09      US  1740624562
# 6              6.08      RO  1740624563
# 7              2.57      US  1740624564

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
sh_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
sh_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                   kupang -10.1667  123.5833     31.32        79          20
# 2              west island -12.1568   96.8225     29.99        89          75
# 4                  petauke -14.2426   31.3253     18.70        97         100
# 8        port-aux-francais -49.3500   70.2167      6.18        73          92
# 11                    lebu -37.6167  -73.6500     13.78        96          23
#
#          Wind Speed Country        Date
# City_ID
# 1              4.12      ID  1740624386
# 2              5.66      CC  1740624559
# 4              1.07      ZM  1740624561
# 8              8.55      TF  1740624565
# 11             4.95      CL  1740624569

# %%
# Linear regression on Northern Hemisphere

linear_regress(nh_df["Lat"].rename("Latitude"), nh_df["Max Temp"], (10, -30))
# Out:
# The r-value is: -0.8608787676700876

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Southern Hemisphere
linear_regress(sh_df["Lat"].rename("Latitude"), sh_df["Max Temp"], (-30, 8))
# Out:
# The r-value is: 0.4489375222519498

# %% [markdown]
# **Discussion about the linear relationship:**
# - There is a sharp negative regression of the northern hamisphere of max temperature and latitude with the correlation coefficient of -0.7825513230046437
# - There is a sharp positive regression of the southern hamisphere of max temperature and latitude with the correlation coefficient of 0.06951634024533657

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(nh_df["Lat"].rename("Latitude"), nh_df["Humidity"], (50, 40))
# Out:
# The r-value is: 0.37221619556930996

# %%
# Southern Hemisphere
linear_regress(sh_df["Lat"].rename("Latitude"), sh_df["Humidity"], (-20, 50))
# Out:
# The r-value is: 0.23782543591310878

# %% [markdown]
# **Discussion about the linear relationship:**
#
# - There seems to have a mild negative regression of humidity in both northern and southern hamisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(nh_df["Lat"].rename("Latitude"), nh_df["Cloudiness"], (42, 50))
# Out:
# The r-value is: 0.16821620387546346

# %%
# Southern Hemisphere
linear_regress(sh_df["Lat"].rename("Latitude"), sh_df["Cloudiness"], (-50, 50))
# Out:
# The r-value is: 0.10289559240424684

# %% [markdown]
# **Discussion about the linear relationship:**
#
# - There seems to be a very mild positive linear regression for both the norther and southern hamisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(nh_df["Lat"].rename("Latitude"), nh_df["Wind Speed"], (10, 12))
# Out:
# The r-value is: 0.07193099823931867

# %%
# Southern Hemisphere
linear_regress(sh_df["Lat"].rename("Latitude"), sh_df["Wind Speed"], (-50, 9))
# Out:
# The r-value is: -0.2860445492556829

# %% [markdown]
# **Discussion about the linear relationship:**
#
# - Wind speed in the norther hamisphere has a positive regression with the correlation coefficient of 0.13573583239553338
# - Wind speed in the southern hamisphere has a negative regression with the correlation coefficient of -0.3386143577396819
# - The two graphs show that the higher the latitude, the higher the wind. The lower the latitude, the wind is lower.
